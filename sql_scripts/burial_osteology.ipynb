# %%
import pandas as pd

df_burials=pd.read_csv("C:/Users/there/Documents/BurialTest.csv")
df_osteology=pd.read_csv("C:/Users/there/Documents/OsteologyTest.csv")
df_burials= df_burials.dropna(axis=1, how='all')
df_osteology
# Out:
#             Location  BurialNumber BodyExaminationDate  BodyPreservationIndex  \
# 0    180 N 40 E NE 1             1            2/7/2002                    3.0
# 1    180 N 40 E NE 2             2            2/7/2002                    3.0
# 2    180 N 40 E NE 2             2           2/13/2002                    NaN
# 3    180 N 40 E NE 3             3            2/7/2002                    6.0
# 4    180 N 40 E NE 4             4            2/7/2002                    4.0
# 5    180 N 40 E NE 5             5           2/17/2002                    4.0
# 6    180 N 40 E NE 5             5            2/9/2002                    6.0
# 7    180 N 40 E NE 6             6            2/9/2002                    6.0
# 8    180 N 40 E NE 7             7            2/9/2002                    4.0
# 9    180 N 40 E NE 8             8            2/9/2002                    NaN
# 10   180 N 40 E NE 9             9           2/17/2002                    3.0
# ...

# %%
df_combined=pd.merge(df_burials, df_osteology, on=['Location', 'BurialNumber'], how='outer')
df_combined
# Out:
#             Location  ExcavationYear  BurialNumber HeadDirection  WestToHead  \
# 0    180 N 40 E NE 6          2002.0             6             W        1.32
# 1    180 N 40 E NE 7          2002.0             7             W        2.70
# 2    180 N 40 E NE 8          2002.0             8             W        1.50
# 3    180 N 40 E NE 9          2002.0             9             W        0.60
# 4   180 N 40 E NE 10          2002.0            10             W        3.06
# 5   180 N 40 E NE 11          2002.0            11             W        1.53
# 6   180 N 40 E NE 12          2002.0            12             E        2.85
# 7   180 N 40 E NE 13          2002.0            13             W        4.57
# 8   180 N 40 E NE 14          2002.0            14             W        3.96
# 9   180 N 40 E NE 15          2002.0            15           NaN        1.94
# 10  180 N 40 E NE 16          2002.0            16             W        1.23
# ...

# %%
print(df_combined.columns)
# Out:
# Index(['Location', 'ExcavationYear', 'BurialNumber', 'HeadDirection',
#        'WestToHead', 'WestToFeet', 'SouthToHead', 'SouthToFeet', 'Depth',
#        'Length', 'ExcavationDay', 'ExcavationMonth', 'BodyPreservationLevel',
#        'WrappingLevel', 'AdultSubadult', 'AgeGroup', 'EstimatedAgeAtDeath',
#        'Sex', 'HairColor_x', 'HasSamples', 'HasFaceBundle', 'HasGraveGoods',
#        'GraveGoodsDescription', 'BurialNotes', 'BodyExaminationDate',
#        'BodyPreservationIndex', 'HairColor_y', 'HairDescription',
#        'RobustCrania', 'SupraorbitalRidgesCrania', 'OrbitEdgeCrania',
#        'ParietalBossingCrania', 'GonionCrania', 'NuchalCrestCrania',
#        'ZygomaticCrestCrania', 'SphenoOccipitalSynchondrosisCrania',
#        'LamboidSutureCrania', 'SquamousSutureCrania', 'ToothAttrition',
#        'ToothEruptionDescription', 'ToothEruptionAgeEstimate',
#        'VentralArcPelvis', 'SubpubicAnglePelvis', 'SciaticNotchPelvis',
# ...

# %%
df_combined= df_combined.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df_combined.to_csv("C:/Users/there/Documents/nine.csv", index=False)

# %%
df_combined=pd.read_csv("C:/Users/there/Documents/CraniaTest.csv")
df_combined= df_combined.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df_combined.to_csv("C:/Users/there/Documents/CraniaTest.csv",index=False, header=False)

# %%
df_combined=pd.read_csv("C:/Users/there/Documents/CraniaTest.csv", header=None)
df_combined
# Out:
#    0                 1     2   3       4       5       6       7      8   \
# 0   1  180 N 40 E NE 21  2002  21  180.70  143.52  126.65   96.77  99.12
# 1  71  180 N 40 E NE 14  2002  14  182.85  134.35  132.93   99.85  90.49
# 2  73  180 N 40 E NE 18  2002  18  184.46  132.27  138.72  100.87  93.53
# 3  74  180 N 40 E NE 26  2002  26  184.97  144.68  143.11  115.81  98.48
# 4  75  180 N 40 E NE 22  2002  22  184.17  138.92  132.37  101.25  93.00
# 5  76  180 N 40 E NE 28  2002  28  162.11  123.09  121.43   97.21  89.98
# 6  84  180 N 40 E NE 19  2002  19  171.70  131.40  125.68   90.80  82.15
#
#        9   ...     12  13  14 15      16      17     18      19      20  \
# 0  121.18  ...  17.20   F   F  1  209.61  160.64 -99.12  482.30  103.07
# 1  120.54  ...  32.67   F   F  1  212.11  165.75 -90.49  479.75  104.98
# 2  119.13  ...  21.81   F   F  1  213.97  167.44 -93.53  474.14  103.75
# 3  136.24  ...  25.29   M   M  1  214.57  192.24 -98.48  542.24  115.53
# ...
